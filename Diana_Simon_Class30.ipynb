# %% [markdown]
# <a href="https://colab.research.google.com/github/dianasimon760-boop/laguardiadataclass/blob/main/Diana_Simon_Class30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT DATA AND VIEW
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', lambda x: f"{x:,.2f}")

sns.set(style='whitegrid')

df = pd.read_csv("https://raw.githubusercontent.com/dianasimon760-boop/laguardiadataclass/refs/heads/main/healthcare_stroke_synthetic%20-%20healthcare_stroke_synthetic.csv")
df.head()
# Out:
#    id  gender  age  hypertension  heart_disease ever_married      work_type  \
# 0   1    Male   50             0              0          Yes  Self-employed
# 1   2  Female   70             0              0          Yes        Private
# 2   3  Female   95             0              1          Yes        Private
# 3   4  Female   47             0              0          Yes        Private
# 4   5    Male   18             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Rural             239.10 45.00           smokes       0
# 1          Rural             210.30 25.60  formerly smoked       0
# 2          Urban             284.30 17.40     never smoked       1
# 3          Rural             280.50 30.80          Unknown       0
# 4          Urban             231.20 49.40     never smoked       0

# %%
df.head(10)
# Out:
#    id  gender  age  hypertension  heart_disease ever_married      work_type  \
# 0   1    Male   50             0              0          Yes  Self-employed
# 1   2  Female   70             0              0          Yes        Private
# 2   3  Female   95             0              1          Yes        Private
# 3   4  Female   47             0              0          Yes        Private
# 4   5    Male   18             0              0          Yes        Private
# 5   6    Male    5             0              0          Yes       Govt_job
# 6   7    Male   83             0              0           No       children
# 7   8  Female   26             0              0           No        Private
# 8   9  Female   52             0              0          Yes       children
# 9  10  Female   47             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# ...

# %%
#Exercises – Section 2
#Show the first 10 rows instead of 5 using df.head(10).
#Use df.sample(5) to view 5 random rows. Why might this be useful?
#Intentionally change file_name to something incorrect and run the cell. What error do you see?
df.sample(5)
# Out:
#         id  gender  age  hypertension  heart_disease ever_married  \
# 64      65    Male   73             0              0           No
# 4855  4856    Male   25             1              0          Yes
# 801    802    Male   11             0              0           No
# 4354  4355  Female   70             0              0          Yes
# 4503  4504    Male   55             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 64          Private          Rural             150.50 49.70         smokes
# 4855        Private          Urban             286.60 36.10   never smoked
# 801   Self-employed          Urban             204.20 34.80   never smoked
# 4354        Private          Rural             139.30 29.20   never smoked
# 4503        Private          Urban             169.70 49.70   never smoked
#
#       stroke
# 64         1
# 4855       0
# 801        0
# 4354       0
# 4503       1

# %%
print('Shape (rows, columns):', df.shape)

print('\nColumn names:')
print(df.columns)

print('\nData types and non-null counts:')
df.info()

print('\nSummary statistics (numeric columns):')
df.describe()
# Out:
# Shape (rows, columns): (5000, 12)
#
# Column names:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')
#
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5000 non-null   int64
#  1   gender             5000 non-null   object
#  2   age                5000 non-null   int64
#  3   hypertension       5000 non-null   int64
#  4   heart_disease      5000 non-null   int64
#  5   ever_married       5000 non-null   object
#  6   work_type          5000 non-null   object
#  7   Residence_type     5000 non-null   object
#  8   avg_glucose_level  5000 non-null   float64
#  9   bmi                5000 non-null   float64
# ...

# %%
#Exercises – Section 3
#How many rows and columns does the dataset have?
#From df.info(), list which columns are numeric and which are object (string-like).
#Run df.describe(include='all') in a new cell. What extra information do you get?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5000 non-null   int64
#  1   gender             5000 non-null   object
#  2   age                5000 non-null   int64
#  3   hypertension       5000 non-null   int64
#  4   heart_disease      5000 non-null   int64
#  5   ever_married       5000 non-null   object
#  6   work_type          5000 non-null   object
#  7   Residence_type     5000 non-null   object
#  8   avg_glucose_level  5000 non-null   float64
#  9   bmi                5000 non-null   float64
#  10  smoking_status     5000 non-null   object
#  11  stroke             5000 non-null   int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 468.9+ KB

# %%
df.describe(include='all')
# Out:
#              id  gender      age  hypertension  heart_disease ever_married  \
# count  5,000.00    5000 5,000.00      5,000.00       5,000.00         5000
# unique      NaN       3      NaN           NaN            NaN            2
# top         NaN  Female      NaN           NaN            NaN          Yes
# freq        NaN    2498      NaN           NaN            NaN         3496
# mean   2,500.50     NaN    49.95          0.10           0.05          NaN
# std    1,443.52     NaN    28.82          0.29           0.22          NaN
# min        1.00     NaN     0.00          0.00           0.00          NaN
# 25%    1,250.75     NaN    25.00          0.00           0.00          NaN
# 50%    2,500.50     NaN    51.00          0.00           0.00          NaN
# 75%    3,750.25     NaN    75.00          0.00           0.00          NaN
# max    5,000.00     NaN    99.00          1.00           1.00          NaN
#
# ...

# %%
#4. Inspect Raw Data & Categorical Columns
#Before cleaning, it's helpful to look at actual values to spot issues such as strange strings or inconsistent categories.

# %%
df.head()
# Out:
#    id  gender  age  hypertension  heart_disease ever_married      work_type  \
# 0   1    Male   50             0              0          Yes  Self-employed
# 1   2  Female   70             0              0          Yes        Private
# 2   3  Female   95             0              1          Yes        Private
# 3   4  Female   47             0              0          Yes        Private
# 4   5    Male   18             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Rural             239.10 45.00           smokes       0
# 1          Rural             210.30 25.60  formerly smoked       0
# 2          Urban             284.30 17.40     never smoked       1
# 3          Rural             280.50 30.80          Unknown       0
# 4          Urban             231.20 49.40     never smoked       0

# %%
df.sample(5, random_state=42)
# Out:
#         id gender  age  hypertension  heart_disease ever_married  \
# 1501  1502   Male   66             0              0           No
# 2586  2587   Male   87             0              0          Yes
# 2653  2654   Male   48             0              0          Yes
# 1055  1056   Male   64             0              0          Yes
# 705    706  Other    9             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 1501        Private          Rural             264.50 38.70     never smoked
# 2586  Self-employed          Rural             179.70 23.10     never smoked
# 2653        Private          Urban             180.20 36.70     never smoked
# 1055  Self-employed          Urban             210.60 35.40  formerly smoked
# 705        Govt_job          Rural             198.70 35.40          Unknown
#
#       stroke
# 1501       1
# 2586       1
# 2653       0
# 1055       0
# 705        0

# %%
# Summary statistics for all columns (numeric + non-numeric)
df.describe(include='all')
# Out:
#              id  gender      age  hypertension  heart_disease ever_married  \
# count  5,000.00    5000 5,000.00      5,000.00       5,000.00         5000
# unique      NaN       3      NaN           NaN            NaN            2
# top         NaN  Female      NaN           NaN            NaN          Yes
# freq        NaN    2498      NaN           NaN            NaN         3496
# mean   2,500.50     NaN    49.95          0.10           0.05          NaN
# std    1,443.52     NaN    28.82          0.29           0.22          NaN
# min        1.00     NaN     0.00          0.00           0.00          NaN
# 25%    1,250.75     NaN    25.00          0.00           0.00          NaN
# 50%    2,500.50     NaN    51.00          0.00           0.00          NaN
# 75%    3,750.25     NaN    75.00          0.00           0.00          NaN
# max    5,000.00     NaN    99.00          1.00           1.00          NaN
#
# ...

# %%
#Exercises – Section 4
#Use df.tail(8) to view the last 8 rows. Do they look similar to the first rows?
#Check unique values of gender using df['gender'].unique().
#Check the frequency of work_type using df['work_type'].value_counts().

# %%
df.tail(8)#view the last 8 rows
# Out:
#         id  gender  age  hypertension  heart_disease ever_married  \
# 4992  4993    Male   63             1              0           No
# 4993  4994  Female   82             0              0          Yes
# 4994  4995    Male   92             0              0          Yes
# 4995  4996  Female    9             0              0          Yes
# 4996  4997    Male   55             0              0          Yes
# 4997  4998    Male   11             1              1           No
# 4998  4999  Female   32             0              0          Yes
# 4999  5000  Female   70             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 4992        Private          Rural             236.90 25.70     never smoked
# 4993        Private          Urban             216.10 42.20           smokes
# 4994   Never_worked          Rural             210.10 38.40          Unknown
# ...

# %%
#Check unique values of gender using df['gender'].unique().
df['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
#Check the frequency of work_type using df['work_type'].value_counts().
df['work_type'].value_counts()
# Out:
# work_type
# Private          2916
# Self-employed     797
# Govt_job          766
# children          427
# Never_worked       94
# Name: count, dtype: int64

# %%
#missingvalues and unique values
print('Missing values per column:')
print(df.isna().sum())

print('\nPercentage of missing values per column:')
print((df.isna().mean() * 100).round(2))

print('\nNumber of unique values per column:')
print(df.nunique())
# Out:
# Missing values per column:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64
#
# Percentage of missing values per column:
# id                  0.00
# gender              0.00
# age                 0.00
# hypertension        0.00
# heart_disease       0.00
# ever_married        0.00
# work_type           0.00
# Residence_type      0.00
# avg_glucose_level   0.00
# bmi                 0.00
# smoking_status      0.00
# stroke              0.00
# dtype: float64
#
# Number of unique values per column:
# id                   5000
# gender                  3
# age                   100
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# ...

# %% [markdown]
# Exercises – Section 5
# Which column has the highest percentage of missing values?
# Approximately what percentage of bmi values are missing?
# How many unique categories does smoking_status have?

# %% [markdown]
# ## 6. Basic Data Cleaning
#
# We will:
# 1. Clean column names (lowercase, replace spaces with underscores)
# 2. Fix special missing values in `bmi` (e.g., 'N/A')
# 3. Convert `bmi` and `avg_glucose_level` to numeric types.

# %%
# 1. Clean column names
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(' ', '_')
      .str.replace('-', '_')
)
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
# Inspect unique values in bmi
df['bmi'].unique()[:20]
# Out:
# array([45. , 25.6, 17.4, 30.8, 49.4, 19.7, 29.2, 22.3, 47.1, 32.9, 34. ,
#        12.3, 36.8, 23.6, 31.5, 32.2, 34.5, 43.3, 23.4, 21.7])

# %%
# Replace 'N/A' with actual NaN and convert to numeric
df['bmi'] = df['bmi'].replace('N/A', np.nan)
df['bmi'] = pd.to_numeric(df['bmi'], errors='coerce')
df['avg_glucose_level'] = pd.to_numeric(df['avg_glucose_level'], errors='coerce')
df[['bmi', 'avg_glucose_level']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   bmi                5000 non-null   float64
#  1   avg_glucose_level  5000 non-null   float64
# dtypes: float64(2)
# memory usage: 78.3 KB

# %%
#Exercises – Section 6
#Add another transformation to the column-name cleaning chain if needed.
#Ensure age is numeric using pd.to_numeric(df['age'], errors='coerce').
#Create a new column age_decade = df['age'] // 10.

# %%
# Inspect unique values in bmi
df['age'].unique()[:20]
# Out:
# array([50, 70, 95, 47, 18,  5, 83, 26, 52,  6, 58, 68, 10, 14, 63,  2, 22,
#        36,  8, 92])

# %%
# Inspect unique values in bmi
df['bmi'] = df['age'].replace('N/A', np.nan)
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5000 entries, 0 to 4999
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 5000 non-null   int64
# dtypes: int64(1)
# memory usage: 39.2 KB

# %%
age_decade = df['age'] // 10

# %%
#7. Handling Missing Values
#We will impute missing numeric values with the median, which is robust to outliers.
# Check missing values again
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
# Median imputation for bmi and avg_glucose_level
bmi_median = df['bmi'].median()
agl_median = df['avg_glucose_level'].median()
df['bmi'] = df['bmi'].fillna(bmi_median)
df['avg_glucose_level'] = df['avg_glucose_level'].fillna(agl_median)
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
# Converting Columns to Categorical
#For columns that represent categories (e.g., gender, work type, hypertension), we convert them to the category dtype.
categorical_cols = [
    'gender', 'ever_married', 'work_type', 'residence_type',
    'smoking_status', 'hypertension', 'heart_disease', 'stroke'
]

for col in categorical_cols:
    df[col] = df[col].astype('category')

df[categorical_cols].dtypes
# Out:
# gender            category
# ever_married      category
# work_type         category
# residence_type    category
# smoking_status    category
# hypertension      category
# heart_disease     category
# stroke            category
# dtype: object

# %%
 #Descriptive Statistics – Numeric Columns

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
numeric_df.describe()
# Out:
#             id      age  avg_glucose_level      bmi
# count 5,000.00 5,000.00           5,000.00 5,000.00
# mean  2,500.50    49.95             173.50    49.95
# std   1,443.52    28.82              72.13    28.82
# min       1.00     0.00              50.00     0.00
# 25%   1,250.75    25.00             111.10    25.00
# 50%   2,500.50    51.00             173.35    51.00
# 75%   3,750.25    75.00             235.80    75.00
# max   5,000.00    99.00             300.00    99.00

# %%
print('Age summary:')
print(df['age'].describe())

print('\nAverage Glucose Level summary:')
print(df['avg_glucose_level'].describe())

print('\nBMI summary:')
print(df['bmi'].describe())
# Out:
# Age summary:
# count   5,000.00
# mean       49.95
# std        28.82
# min         0.00
# 25%        25.00
# 50%        51.00
# 75%        75.00
# max        99.00
# Name: age, dtype: float64
#
# Average Glucose Level summary:
# count   5,000.00
# mean      173.50
# std        72.13
# min        50.00
# 25%       111.10
# 50%       173.35
# 75%       235.80
# max       300.00
# Name: avg_glucose_level, dtype: float64
#
# BMI summary:
# count   5,000.00
# mean       49.95
# std        28.82
# min         0.00
# 25%        25.00
# 50%        51.00
# 75%        75.00
# max        99.00
# Name: bmi, dtype: float64

# %%
#Descriptive Statistics – Categorical Column
def show_category_distribution(col_name):
    counts = df[col_name].value_counts()
    percents = df[col_name].value_counts(normalize=True) * 100
    display(pd.DataFrame({'count': counts, 'percent': percents.round(2)}))

for col in ['gender', 'ever_married', 'work_type', 'residence_type', 'smoking_status', 'stroke']:
    print(f'--- {col} ---')
    show_category_distribution(col)
    print()
# Out:
# --- gender ---
#         count  percent
# gender
# Female   2498    49.96
# Male     2405    48.10
# Other      97     1.94
# --- ever_married ---
#               count  percent
# ever_married
# Yes            3496    69.92
# No             1504    30.08
# --- work_type ---
#                count  percent
# work_type
# Private         2916    58.32
# Self-employed    797    15.94
# Govt_job         766    15.32
# children         427     8.54
# Never_worked      94     1.88
# --- residence_type ---
#                 count  percent
# residence_type
# Rural            2506    50.12
# Urban            2494    49.88
# --- smoking_status ---
#                  count  percent
# smoking_status
# never smoked      2474    49.48
# formerly smoked    996    19.92
# smokes             783    15.66
# Unknown            747    14.94
# --- stroke ---
#         count  percent
# stroke
# 0        3593    71.86
# 1        1407    28.14

# %%
#Univariate Visualizations – Numeric  - histogram plot
fig, axes = plt.subplots(1, 3, figsize=(18, 4))

sns.histplot(df['age'], bins=30, kde=True, ax=axes[0])
axes[0].set_title('Age Distribution')

sns.histplot(df['avg_glucose_level'], bins=30, kde=True, ax=axes[1])
axes[1].set_title('Average Glucose Level Distribution')

sns.histplot(df['bmi'], bins=30, kde=True, ax=axes[2])
axes[2].set_title('BMI Distribution')

plt.tight_layout()
plt.show()

# %%
#Univariate Visualizations – Numeric  -  boxplot
ig, axes = plt.subplots(1, 3, figsize=(18, 4))

sns.boxplot(y=df['age'], ax=axes[0])
axes[0].set_title('Age Boxplot')

sns.boxplot(y=df['avg_glucose_level'], ax=axes[1])
axes[1].set_title('Avg Glucose Level Boxplot')

sns.boxplot(y=df['bmi'], ax=axes[2])
axes[2].set_title('BMI Boxplot')

plt.tight_layout()
plt.show()

# %% [markdown]
# Exercises – Section 11
# Which numeric variable appears most skewed?
#
# Which variable shows the most extreme outliers in the boxplots?
#
# Create a single histogram of age with bins=15 and add a title and axis labels.

# %%
#Univariate Visualizations – Categorical box plot

plt.figure(figsize=(6, 4))
sns.countplot(x='gender', data=df)
plt.title('Gender Distribution')
plt.show()

plt.figure(figsize=(8, 4))
sns.countplot(x='work_type', data=df)
plt.title('Work Type Distribution')
plt.xticks(rotation=30)
plt.show()

plt.figure(figsize=(8, 4))
sns.countplot(x='smoking_status', data=df)
plt.title('Smoking Status Distribution')
plt.xticks(rotation=30)
plt.show()

plt.figure(figsize=(4, 4))
sns.countplot(x='stroke', data=df)
plt.title('Stroke vs No Stroke')
plt.sho
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1435/3345278656.py in <cell line: 0>()
#      21 sns.countplot(x='stroke', data=df)
#      22 plt.title('Stroke vs No Stroke')
# ---> 23 plt.sho
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sho'

# %% [markdown]
# Exercises – Section 12
# Which work_type category has the smallest count?
# What do you notice about the class balance of stroke (0 vs 1)?
# Create a countplot for residence_type.

# %%
#Bivariate Analysis – Stroke vs Risk Factors

# %%
# Mean age, glucose, BMI by stroke status
grouped_stroke = df.groupby('stroke')[['age', 'avg_glucose_level', 'bmi']].mean().round(2)
grouped_stroke
# Out:
# /tmp/ipykernel_1435/2816416798.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_stroke = df.groupby('stroke')[['age', 'avg_glucose_level', 'bmi']].mean().round(2)
#          age  avg_glucose_level   bmi
# stroke
# 0      45.81             168.56 45.81
# 1      60.50             186.11 60.50

# %%
# Age distribution by stroke status
plt.figure(figsize=(8, 4))
sns.kdeplot(data=df, x='age', hue='stroke', shade=True)
plt.title('Age Distribution by Stroke Status')
plt.show()
# Out:
# /tmp/ipykernel_1435/3303751628.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='age', hue='stroke', shade=True)

# %%
# BMI by stroke status
plt.figure(figsize=(6, 4))
sns.boxplot(x='stroke', y='bmi', data=df)
plt.title('BMI by Stroke Status')
plt.show()

# %%
# Hypertension vs stroke
ct_hyper = pd.crosstab(df['hypertension'], df['stroke'], normalize='index') * 100
ct_hyper.round(2)
# Out:
# stroke           0     1
# hypertension
# 0            74.03 25.97
# 1            51.46 48.54

# %%
ct_hyper.plot(kind='bar', stacked=True, figsize=(6, 4))
plt.title('Stroke Rate by Hypertension Status (%)')
plt.xlabel('Hypertension (0 = No, 1 = Yes)')
plt.ylabel('Percentage')
plt.legend(title='Stroke', labels=['No Stroke (0)', 'Stroke (1)'])
plt.show()

# %% [markdown]
# #Exercises – Section 13
# #How do the mean age and avg_glucose_level differ between stroke #and no-stroke groups?
# #In the KDE plot, which group appears older on average?
# #Create a similar crosstab and stacked bar chart for heart_disea

# %%
#Correlation Matrix – Numeric Features
corr_matrix = df.select_dtypes(include=['int64', 'float64']).corr()
corr_matrix
# Out:
#                     id  age  avg_glucose_level  bmi
# id                1.00 0.02               0.01 0.02
# age               0.02 1.00               0.00 1.00
# avg_glucose_level 0.01 0.00               1.00 0.00
# bmi               0.02 1.00               0.00 1.00

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %% [markdown]
# Exercises – Section 14
# Which pair of numeric variables has the strongest positive correlation?
# Which variable is most correlated with age?
# Does any variable show surprisingly low correlation with stroke? Why might that be?

# %%
output_file = 'healthcare-stroke-data-cleaned.csv'
df.to_csv(output_file, index=False)
print(f'Cleaned data saved to: {output_file}')
# Out:
# Cleaned data saved to: healthcare-stroke-data-cleaned.csv
